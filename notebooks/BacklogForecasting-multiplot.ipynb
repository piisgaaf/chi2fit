# %% [markdown]
# # Throughput - Multiple Teams - Multi-plot

# %% [markdown]
# Fitting data to known distributions use is done using [Chi2Fit](https://hex.pm/packages/chi2fit).
#
# This note contains an example analysis for 6 teams.

# %% [markdown]
# This note demonstrates how to use the multi-plot feature of GNUplot.

# %% [markdown]
# ## Table of contents

# %% [markdown]
# * [Set-up](#Set-up)
# * [Data and simulation set-up](#Data-and-simulation-set-up)
# * [Analyze the data](#Analyze-the-data)
# * [Fitting the data to a Poisson distribution](#Fitting-the-data-to-a-Poisson-distribution)
# * [Forecasting using a Poisson distribution](#Monte-Carlo)
# * [References](#Forecasting-using-a-Poisson-distribution)
# * [Tear-down](#Tear-down)

# %% [markdown]
# ## Set-up

# %%
alias Chi2fit.Distribution, as: D
alias Chi2fit.Fit, as: F
alias Chi2fit.Matrix, as: M
alias Chi2fit.Utilities, as: U
alias Gnuplotlib, as: P
alias Gnuplot, as: G
alias Exboost.Math
# Out:
# Exboost.Math

# %% [markdown]
# ## Data and simulation set-up

# %% [markdown]
# As an example consider the throughput of completed backlog items. At the end of a fixed time period we count the number of backlog items that a team completes. Partially completed items are excluded from the count.

# %% [markdown]
# The periods for (almost) all teams in this note is 15 days (half a month). Two periods equals 1 month. For most of the data a bin size of 5 is appropriate. This is made specific in the structure describing the team data below.

# %%
# The time period (in days) that the throughput data is collected
period = 15

# The size of the bins
binsize = 5
:"do not show this result in output"

# %% [markdown]
# The following shows the sequences for the throughput (number of work items completed per period) for six teams. The most recent period is the first item in the list. Note that fort all teams the global bin size (see above) applies except for teams 5 for which we will use a bin size of 5.

# %%
all_data = %{
    "Team 1" => [69,41,53,41,41,48,69,15,15,12,12,15,31,78,62,16,25,28,25,38,16],
    "Team 2" => [50,68,36,50,50,68,36,19,15,23,9,15,3,23,23,9,14,2,9,9,14,19,11,0,1,1,1],
    "Team 3" => [55,46,46,70,55,70,91,67,49,7,20,34,68,68,20,31,0,0,0,0,0,4,0,0,0,3],
    "Team 4" => [55,47,65,50,50,50,57,44,27,25,14,23,30],
    "Team 5" => [
        throughput: [11,4,11,3,6,0],
        bin: 1
    ],
    "Team 6" => [70,70,86,116,70,103,103,116,73,28,28,35,26,35,70,32,32,26,60,37,19,37,19,16,10,13,31,37,31,24,16,37,3,2,2,4,2,2],
}
:"do not show this result in output"

# %% [markdown]
# Parameters that affect the Monte Carlo simulations are listed below. Please adjust to your needs.

# %%
# Number of iterations to use in the Monte Carlo
iterations = 1000

# Number of probes to use in the chi2 fit
probes = 10_000

# The range of the parameter to look for a (global) minimum
initial = {1,100}
:"do not show this result in output"

# %% [markdown]
# Later on in this note we will forecast to provide a statistical answer to the questions:
# 1. How many periods do we need to complete a certain amount of work items?
# 1. How many work items can the team complete in a certain amount of periods?

# %%
# The size of the backlog, e.g. 100 backlog items
size = 1000

# The number of periods to forecast the number of completed work items
periods = 6
:"do not show this result in output"

# %% [markdown]
# We will start by showing a histogram of the raw throughput data:

# %%
P.multi([
    P.histogram(all_data["Team 1"], bin: 5, plottitle: "1 (bi-weekly)", ylabel: "Frequency", xrange: '[0:80]', yrange: '[:5]', commands: true),
    P.histogram(all_data["Team 2"], bin: 5, plottitle: "2 (bi-weekly)", xrange: '[0:80]', yrange: '[:10]', commands: true),
    P.histogram(all_data["Team 3"], bin: 5, plottitle: "3 (bi-weekly)", xrange: '[0:120]', yrange: '[:10]', commands: true),
    P.histogram(all_data["Team 4"], bin: 5, plottitle: "4 (bi-weekly)", xlabel: "Throughput", ylabel: "Frequency", xrange: '[0:80]', yrange: '[:5]', commands: true),
    P.histogram(all_data["Team 5"][:throughput], bin: 1, xlabel: "Throughput", plottitle: "5 (monthly)", xrange: '[0:30]', yrange: '[:5]', commands: true),
    P.histogram(all_data["Team 6"], bin: 5, xlabel: "Throughput", plottitle: "6 (bi-weekly)", xrange: '[0:160]', yrange: '[:10]', commands: true),
], columns: 3, title: "Throughput data for 6 teams", inline: "mhist", size: "1200,600")
:timer.sleep(1000)
{:"this is an inline image", src: "/app/notebooks/images/mhist.png"}

# %% [markdown]
# ## Analyze the data

# %% [markdown]
# We will use the Poisson distribution to model the squad data.

# %%
model = D.model "poisson"
options = [probes: probes, model: :linear, fitmodel: model, init: initial, bin: binsize]
:"do not show this result in output"

# %% [markdown]
# Next, we analyze the team data to find any (sudden) changes in the delivery rate, or throughput. We are interested in the most recent largest sequence of data that corresponds to the same delivery rate.

# %%
recent = U.analyze(
    all_data,
    fn data,opt ->
        [{chi,params,subdata}|_] = F.find_all(data[:throughput],opt)
        [
            throughput: subdata,
            parameters: params,
            minchi2: chi
        ]
    end,
    options)
|> IO.inspect(charlists: :as_lists)
:"do not show this result in output"
# Out:
# %{
#   "Team 1" => [
#     bin: 5,
#     throughput: [69, 41, 53, 41, 41, 48, 69],
#     parameters: [49.043918056504545],
#     minchi2: 0.22736552185371556
#   ],
#   "Team 2" => [
#     bin: 5,
#     throughput: [50, 68, 36, 50, 50, 68, 36],
#     parameters: [45.59082585578629],
#     minchi2: 0.035766088136411224
#   ],
#   "Team 3" => [
#     bin: 5,
#     throughput: [55, 46, 46, 70, 55, 70, 91, 67, 49],
#     parameters: [55.70765882438914],
#     minchi2: 0.3657528845970432
#   ],
#   "Team 4" => [
#     bin: 5,
#     throughput: [55, 47, 65, 50, 50, 50, 57, 44, 27],
#     parameters: [45.79182132046337],
#     minchi2: 6.944388084947495
#   ],
#   "Team 5" => [
#     bin: 1,
#     throughput: [11, 4, 11, 3, 6, 0],
#     parameters: [4.023309376772683],
#     minchi2: 2.9977920999105976
#   ],
#   "Team 6" => [
#     bin: 5,
#     throughput: [70, 70, 86, 116, 70],
#     parameters: [74.46193015800957],
#     minchi2: 1.2094139458981965
#   ]
# }

# %%
P.multi([
    P.histogram(recent["Team 1"][:throughput], bin: 5, plottitle: "1 (bi-weekly)", ylabel: "Frequency", xrange: '[0:80]', yrange: '[:5]', commands: true),
    P.histogram(recent["Team 2"][:throughput], bin: 5, plottitle: "2 (bi-weekly)", xrange: '[0:80]', yrange: '[:10]', commands: true),
    P.histogram(recent["Team 3"][:throughput], bin: 5, plottitle: "2 (bi-weekly)", xrange: '[0:120]', yrange: '[:10]', commands: true),
    P.histogram(recent["Team 4"][:throughput], bin: 5, plottitle: "3 (bi-weekly)", ylabel: "Frequency", xlabel: "Throughput", xrange: '[0:80]', yrange: '[:5]', commands: true),
    P.histogram(recent["Team 5"][:throughput], bin: 1, plottitle: "4 (monthly)", xlabel: "Throughput", xrange: '[0:30]', yrange: '[:5]', commands: true),
    P.histogram(recent["Team 6"][:throughput], bin: 5, plottitle: "5 (bi-weekly)", xlabel: "Throughput", xrange: '[0:160]', yrange: '[:10]', commands: true),
], columns: 3, title: "Throughput data for 6 teams", inline: "mhist_update", size: "1200,600")
:timer.sleep(1000)
{:"this is an inline image", src: "/app/notebooks/images/mhist_update.png"}

# %% [markdown]
# ## Fitting the data to a Poisson distribution

# %% [markdown]
# Instead of directly using the raw data captured one can also use a known probability distribution. The parameter of the distribution is matched to the data. After matching the parameter value one uses the known distribution to forecast.

# %% [markdown]
# Here, we will use the __Poisson distribution__ [1]. This basically assumes that the data points are independent of each other. For most teams we expect this to be a more than reasonable choice.

# %%
fits = recent
|> U.analyze(
    fn dat,opt ->
        try do
            {chi2, cov, params, ranges} = dat[:throughput]
                |> U.to_bins({opt[:bin],0})
                |> F.chi2fit({dat[:parameters], model[:fun], &F.nopenalties/2}, 10, opt)
            [
                minchi2: chi2,
                parameters: params,
                errors: Enum.zip(cov|>M.diagonal|>Enum.map(&:math.sqrt/1), tl(Tuple.to_list(ranges)))
            ]
        catch
            {:inverse_error, ArithmeticError, chi2, parameters} ->
            [
                minchi2: chi2,
                parameters: parameters
            ]
        end
    end,
    options |> Keyword.replace!(:probes,[]))
|> IO.inspect(charlists: :as_lists)
:"do not show this result in output"
# Out:
# %{
#   "Team 1" => [
#     bin: 5,
#     throughput: [69, 41, 53, 41, 41, 48, 69],
#     minchi2: 0.2273646456134518,
#     parameters: [49.04652348797751],
#     errors: [{2.783525074616179, [49.041606186992794, 49.046653132519076]}]
#   ],
#   "Team 2" => [
#     bin: 5,
#     throughput: [50, 68, 36, 50, 50, 68, 36],
#     minchi2: 0.035766035133983354,
#     parameters: [45.58974278048748],
#     errors: [{4.7043987017587225, [45.58954130683182, 45.59082585578629]}]
#   ],
#   "Team 3" => [
#     bin: 5,
#     throughput: [55, 46, 46, 70, 55, 70, 91, 67, 49],
#     minchi2: 0.36575242307175104,
#     parameters: [55.70925597658652],
#     errors: [{2.3510098026264683, [55.70765882438914, 55.710485373203134]}]
#   ],
#   "Team 4" => [
#     bin: 5,
#     throughput: [55, 47, 65, 50, 50, 50, 57, 44, 27],
#     minchi2: 6.9443399301168585,
#     parameters: [45.78713058901157],
#     errors: [{0.676004597271051, [45.785471971030574, 45.79431879290604]}]
#   ],
#   "Team 5" => [
# ...

# %% [markdown]
# ## Forecasting using a Poisson distribution

# %% [markdown]
# For a (local) minimum the value of the gradient should be very close to zero which is the case. The value of chi-squared at the minimum is much, much smaller than 1. Usually values below 1 indicate a very good fit. Large errors on the data make it easy to fit a curve resulting in low values for chi-squared. Here, it means that the errors in the data are large.

# %%
t1 = fits["Team 1"]
t2 = fits["Team 2"]
t3 = fits["Team 3"]
t4 = fits["Team 4"]
t5 = fits["Team 5"]
t6 = fits["Team 6"]
:"do not show this result in output"

# %%
P.multi([
    P.ecdf(t1[:throughput] |> U.to_bins({5,0}),plottitle: "1 (bi-weekly)",ylabel: "Probability",title: "Poisson",func: D.poissonCDF(hd(t1[:parameters])),commands: true),
    P.ecdf(t2[:throughput] |> U.to_bins({5,0}),plottitle: "2 (bi-weekly)",title: "Poisson",func: D.poissonCDF(hd(t2[:parameters])),commands: true),
    P.ecdf(t3[:throughput] |> U.to_bins({5,0}),plottitle: "3 (bi-weekly)",title: "Poisson",func: D.poissonCDF(hd(t3[:parameters])),commands: true),
    P.ecdf(t4[:throughput] |> U.to_bins({5,0}),plottitle: "4 (bi-weekly)",xlabel: "Throughput",ylabel: "Probability",title: "Poisson",func: D.poissonCDF(hd(t4[:parameters])),commands: true),

    P.ecdf(t5[:throughput] |> U.to_bins({1,0}),plottitle: "5 (monthly)",xlabel: "Throughput",title: "Poisson",func: D.poissonCDF(hd(t5[:parameters])),commands: true),
    P.ecdf(t6[:throughput] |> U.to_bins({5,0}),plottitle: "6 (bi-weekly)",xlabel: "Throughput",title: "Poisson",func: D.poissonCDF(hd(t6[:parameters])),commands: true)
], columns: 3, title: "CDF of throughput data for 6 teams", inline: "mecdf", size: "1200,900")
:timer.sleep(1000)
{:"this is an inline image", src: "/app/notebooks/images/mecdf.png"}

# %%
# Define the probability density for the Poisson distribution
poisson = fn x,[par] -> :math.exp(x*:math.log(par) - par - Math.lgamma(x+1.0)) end
# Out:
# #Function<12.127694169/2 in :erl_eval.expr/5>

# %%
P.multi([
    P.pdf(t1[:throughput], plottitle: "1 (bi-weekly)",ylabel: "Frequency",yrange: '[0:0.10]',pdf: &poisson.(&1,t1[:parameters]),title: "Poisson",bin: t1[:bin],commands: true),
    P.pdf(t2[:throughput], plottitle: "2 (bi-weekly)",yrange: '[0:0.10]',pdf: &poisson.(&1,t2[:parameters]),title: "Poisson",bin: t2[:bin],commands: true),
    P.pdf(t3[:throughput], plottitle: "3 (bi-weekly)",yrange: '[0:0.10]',pdf: &poisson.(&1,t3[:parameters]),title: "Poisson",bin: t3[:bin],commands: true),
    P.pdf(t4[:throughput], plottitle: "4 (bi-weekly)",xlabel: "Throughput",ylabel: "Frequency",yrange: '[0:0.10]',pdf: &poisson.(&1,t4[:parameters]),title: "Poisson",bin: t4[:bin],commands: true),

    P.pdf(t5[:throughput], plottitle: "5 (monthly)",xlabel: "Throughput",yrange: '[0:0.60]',pdf: &poisson.(&1,t5[:parameters]),title: "Poisson",bin: t5[:bin],commands: true),
    P.pdf(t6[:throughput], plottitle: "6 (bi-weekly)",xlabel: "Throughput",yrange: '[0:0.10]',pdf: &poisson.(&1,t6[:parameters]),title: "Poisson",bin: t6[:bin],commands: true),
],columns: 3, title: "PDF of throughput data for 6 teams", inline: "mpdf", size: "1200,800")
:timer.sleep(1000)
{:"this is an inline image", src: "/app/notebooks/images/mpdf.png"}

# %% [markdown]
# Again, using a Monte Carlo simulation we estimate the number of iterations and the range to expect.

# %%
mc = fits
|> U.analyze(fn dat,opt ->
        [rate] = dat[:parameters]
        {avg,sd,all} = U.mc(iterations, fn -> U.forecast(D.poisson(rate), size) end, true)

        [
            mc_size: %{
                "avg" => avg,
                "sd" => sd,
                "50%" => avg,
                "84%" => avg+sd,
                "97.5%" => avg+2*sd,
                "99.85%" => avg+3*sd,
                "all" => all
            }
        ]
    end,
    options)
|> U.analyze(fn dat,opt ->
        [rate] = dat[:parameters]
        {avg,sd,all} = U.mc(iterations, fn -> U.forecast(fn -> 1 end, periods, 0, D.poisson(rate)) end, true)
        [
            mc_periods: %{
                "avg" => avg,
                "sd" => sd,
                "50%" => avg,
                "84%" => avg+sd,
                "97.5%" => avg+2*sd,
                "99.85%" => avg+3*sd,
                "all" => all
            }
        ]
    end,
    options)
|> IO.inspect(charlists: :as_lists)
:"do not show this result in output"
# Out:
# %{
#   "Team 1" => [
#     bin: 5,
#     throughput: [69, 41, 53, 41, 41, 48, 69],
#     minchi2: 0.2273646456134518,
#     parameters: [49.04652348797751],
#     errors: [{2.783525074616179, [49.041606186992794, 49.046653132519076]}],
#     mc_size: %{
#       "50%" => 20.932,
#       "84%" => 21.60235512976332,
#       "97.5%" => 22.27271025952664,
#       "99.85%" => 22.943065389289963,
#       "all" => [21, 21, 21, 21, 20, 21, 21, 20, 21, 20, 21, 20, 20, 20, 21, 21,
#        20, 21, 20, 22, 21, 21, 21, 21, 20, 22, 21, 21, 21, 21, 21, 21, 21, 22,
#        22, 22, 20, 21, ...],
#       "avg" => 20.932,
#       "sd" => 0.6703551297633213
#     },
#     mc_periods: %{
#       "50%" => 293.615,
#       "84%" => 310.6973527360841,
#       "97.5%" => 327.7797054721682,
#       "99.85%" => 344.8620582082523,
#       "all" => [297, 304, 287, 304, 327, 271, 304, 278, 294, 278, 282, 295, 321,
#        286, 291, 291, 310, 286, 303, 302, 297, 310, 280, 283, 291, 299, 291,
# ...

# %%
t1 = mc["Team 1"]
t2 = mc["Team 2"]
t3 = mc["Team 3"]
t4 = mc["Team 4"]
t5 = mc["Team 5"]
t6 = mc["Team 6"]
:"do not show this result in output"

# %%
P.multi([
    P.histogram(t1[:mc_size]["all"],plottitle: "1 (bi-weekly)",ylabel: "Frequency",commands: true),
    P.histogram(t2[:mc_size]["all"],plottitle: "2 (bi-weekly)",commands: true),
    P.histogram(t3[:mc_size]["all"],plottitle: "3 (bi-weekly)",commands: true),
    P.histogram(t4[:mc_size]["all"],plottitle: "4 (bi-weekly)",xlabel: "Duration (number of periods)",ylabel: "Frequency",commands: true),

    P.histogram(t5[:mc_size]["all"],plottitle: "5 (monthly)",xlabel: "Duration (number of periods)",commands: true),
    P.histogram(t6[:mc_size]["all"],plottitle: "6 (bi-weekly)",xlabel: "Duration (number of periods)",commands: true),
],columns: 3, title: "Forecast for completing #{size} work items", inline: "mperiods", size: "1200,600")
:timer.sleep(1000)
{:"this is an inline image", src: "/app/notebooks/images/mperiods.png"}

# %%
P.multi([
    P.histogram(t1[:mc_periods]["all"],plottitle: "1 (bi-weekly)",ylabel: "Frequency",commands: true),
    P.histogram(t2[:mc_periods]["all"],plottitle: "2 (bi-weekly)",commands: true),
    P.histogram(t3[:mc_periods]["all"],plottitle: "3 (bi-weekly)",commands: true),
    P.histogram(t4[:mc_periods]["all"],plottitle: "4 (bi-weekly)",xlabel: "Number of work items",ylabel: "Frequency",commands: true),

    P.histogram(t5[:mc_periods]["all"],plottitle: "5 (monthly)",xlabel: "Number of work items",commands: true),
    P.histogram(t6[:mc_periods]["all"],plottitle: "6 (bi-weekly)",xlabel: "Number of work items",commands: true),
],columns: 3, title: "Forecast for completed work items after #{periods} periods", inline: "mwork", size: "1200,600")
:timer.sleep(1000)
{:"this is an inline image", src: "/app/notebooks/images/mwork.png"}

# %% [markdown]
# ## References

# %% [markdown]
# [1] _Poisson distribution_, https://en.wikipedia.org/wiki/Poisson_distribution/<br>
# [2] _Chi2Fit_, Pieter Rijken, 2018, https://hex.pm/packages/chi2fit<br>
# [3] _Asymmetric errors_, Roger Barlow, Manchester University, UK and Stanford University, USA, PHYSTAT2003, SLAC, Stanford, California, September 8-11, 2003, https://www.slac.stanford.edu/econf/C030908/papers/WEMT002.pdf<br>
# [4] _Efficient use of Monte Carlo: uncertainty propagation_, D. Rochman et. al., Nuclear Science and Engineering, 2013, ftp://ftp.nrg.eu/pub/www/talys/bib_rochman/fastTMC.pdf
